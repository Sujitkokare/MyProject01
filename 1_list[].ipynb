# %%
mylist = [10,20,30,'Python',45.45,True]

# %%
mylist
# Out:
# [10, 20, 30, 'Python', 45.45, True]

# %%
print(mylist)
# Out:
# [10, 20, 30, 'Python', 45.45, True]

# %%
mylist.append(False)

# %%
t = (10,20,59,45, [100,200,300],50)

# %%
t[4].append(500)

# %%
t
# Out:
# (10, 20, 59, 45, [100, 200, 300, 500], 50)

# %%
t[4]
# Out:
# [100, 200, 300, 500]

# %%
t.append(50)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 t.append(50)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
t1 = [10,20,59,45, (100,200,300),50]

# %%
t1[4]
# Out:
# (100, 200, 300)

# %%
t.count(50)
# Out:
# 1

# %%
t.count(1000000)
# Out:
# 0

# %%
pack = 12,34,56,78,45,"Python"

# %%
pack
# Out:
# (12, 34, 56, 78, 45, 'Python')

# %%
a,b,c = 10,20,30

# %%
a
# Out:
# 10

# %%
a,b,c,d,e,f = pack

# %%
a
# Out:
# 12

# %%
list1 = [100,200]

# %%
a,b = list1

# %%
a
# Out:
# 100

# %%
b
# Out:
# 200

# %%
print(a,b)
# Out:
# 100 200

# %%
t1 = 100,200,300

# %%
t1
# Out:
# (100, 200, 300)

# %%
x,y,z = t1

# %%
x,y,z
# Out:
# (100, 200, 300)

# %%
l2 = 100,200,300

# %%
l2
# Out:
# (100, 200, 300)

# %%
list1 = [45,78,24,57,90,35,1,67,0.5]
list1.sort()

# %%
list1
# Out:
# [0.5, 1, 24, 35, 45, 57, 67, 78, 90]

# %%
list1.reverse()

# %%
list1
# Out:
# [90, 78, 67, 57, 45, 35, 24, 1, 0.5]

# %%
list2 = [45,78,24,57,90,35,1,67,0.5]
list2.reverse()
list2
# Out:
# [0.5, 67, 1, 35, 90, 57, 24, 78, 45]

# %% [markdown]
# $$list$$

# %%
my_list = ['A']

# %%
ord('A')
# Out:
# 65

# %%
chr(65)
# Out:
# 'A'

# %%
my_list.append(100)

# %%
my_list
# Out:
# ['A', 100]

# %%
my_list.insert(1,'B')

# %%
my_list
# Out:
# ['A', 'B', 100]

# %%
my_list.pop()
# Out:
# 100

# %%
my_list.pop(0)
# Out:
# 'A'

# %%
my_list.pop[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 my_list.pop[0]
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %%
my_list.pop()
# Out:
# 'B'

# %%
my_list.extend([100,200,300])

# %%
my_list
# Out:
# [100, 200, 300]

# %%
x = eval(input())
# Out:
#  abc
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 x = eval(input())
#
# File <string>:1
#
# NameError: name 'abc' is not defined

# %%
list1 = (12,34,56,67)

# %%
a,b,*c= list1

# %%
list1
# Out:
# [12, 34, 56, 67]

# %%
a
# Out:
# 12

# %%
c
# Out:
# [56, 67]

# %%
t1 = (12,34,56,67,86,46)

# %%
a,*b = t1

# %%
a
# Out:
# 12

# %%
b
# Out:
# [34, 56, 67, 86, 46]

# %%
type(b)
# Out:
# list

# %%
list2 = [100,50]

# %%
tuple(list2)
# Out:
# (100, 50)

# %%
type(a)
# Out:
# tuple

# %%
list3 = list(a)

# %%
type(list3)
# Out:
# list

# %%
x = 200

# %%
(input())
# Out:
#  555
# '555'

# %%
a,*my_list = 1, 2, 3, 4

# %%
a
# Out:
# 1

# %%
my_list
# Out:
# [2, 3, 4]

# %%
my_set = {1,500, 2, 3, 2, 4}

# %%
my_set
# Out:
# {1, 2, 3, 4, 500}

# %%
my_set
# Out:
# {1, 2, 3, 4, 500}

# %%
my_set
# Out:
# {1, 2, 3, 4, 500}

# %%
my_set
# Out:
# {1, 2, 3, 4, 500}

# %%
mylist = [1,2,3,4,5,5,6,7,8,8,9,'one','two','three']
mylist.count(5)
